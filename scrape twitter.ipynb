# %%
import csv
from getpass import getpass
from time import sleep 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchAttributeException
from msedge.selenium_tools import Edge, EdgeOptions

def get_tweet_data(card):
    #extract data from tweet
    username = card.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[2]/div/section/div/div/div[1]/div/div/article/div/div/div/div[2]/div[2]/div[1]/div/div').text
    handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text
    try:
        postdate = card.find_element_by_xpath('//time').get_attribute('datetime')
    except NoSuchAttributeException:
        return
    comment = card.find_element_by_xpath ('//div[2]/div[2]/div[1]').text
    responding = card.find_element_by_xpath('//div[2]/div[2]/div[2]').text 
    text =comment + responding
    reply_cnt = card.find_element_by_xpath ('.//div[@data-testid="reply"]').text
    retweet_cnt = card.find_element_by_xpath ('.//div[@data-testid="retweet"]').text
    like_cnt =  card.find_element_by_xpath ('.//div[@data-testid="like"]').text
    tweet = (username, handle, postdate ,text, reply_cnt, retweet_cnt, like_cnt)
        
    return tweet

# create 
options = EdgeOptions()
options.use_chromium = True
driver = webdriver.Edge(r'C:\\Users\\jchih\\Downloads\\edgedriver_win64\\msedgedriver.exe')
sleep(3)
#Login
driver.get('https://twitter.com/login')
sleep(5)
username = driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[5]/label').send_keys('jamazichiheb')
driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[6]').click()
sleep(3)
password = driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[3]/div/label/div/div[2]/div[1]/input').send_keys('Seawaymn2011&&')
sleep(3)
driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]').click()
sleep(4)
import csv
from getpass import getpass
from time import sleep 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchAttributeException
from msedge.selenium_tools import Edge, EdgeOptions


search_input = driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div/div/form/div[1]/div/div/label/div[2]/div/input')
search_input.send_keys('#RussiaUkraineWar ')
search_input.send_keys(Keys.RETURN)
driver.find_element_by_link_text('Latest').click()
sleep(5)
#get all tweets
data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True
while scrolling :
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
    for card in page_cards[-15:]: 
        tweet= get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                data.append(tweet)
        
    scroll_attempt = 0
    
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(1)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2)
        else:
            last_position = curr_position
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10604/3345882469.py in <module>
#      74         driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
#      75         sleep(1)
# ---> 76         curr_position = driver.execute_script("return window.pageYOffset;")
#      77         if last_position == curr_position:
#      78             scroll_attempt += 1
#
# ~\anaconda3\envs\scraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\anaconda3\envs\scraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
# ...

# %%
import csv
from getpass import getpass
from time import sleep 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchAttributeException
from msedge.selenium_tools import Edge, EdgeOptions

# create 
options = EdgeOptions()
options.use_chromium = True
driver = webdriver.Edge(r'C:\\Users\\jchih\\Downloads\\edgedriver_win64\\msedgedriver.exe')
sleep(3)
#Login
driver.get('https://twitter.com/login')
sleep(5)
username = driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[5]/label').send_keys('jamazichiheb')
driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[6]').click()
sleep(3)
password = driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[3]/div/label/div/div[2]/div[1]/input').send_keys('Seawaymn2011&&')
sleep(3)
driver.find_element_by_xpath('//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]').click()
sleep(4)

# %%
driver.get('https://twitter.com/accenture')
data = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")

# %%
import time
SCROLL_PAUSE_TIME = 1.5
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    #uncomment to limit the number of scrolls
    #scroll_number += 1
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    company_page = driver.page_source

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = "https://twitter.com/accenture"
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

# %%
def get_tweet_data(card):
    #extract data from tweet
    username = card.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[2]/div/section/div/div/div[1]/div/div/article/div/div/div/div[2]/div[2]/div[1]/div/div').text
    handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text
    try:
        postdate = card.find_element_by_xpath('//time').get_attribute('datetime')
    except NoSuchAttributeException:
        return
    comment = card.find_element_by_xpath ('//div[2]/div[2]/div[1]').text
    responding = card.find_element_by_xpath('//div[2]/div[2]/div[2]').text 
    text =comment + responding
    reply_cnt = card.find_element_by_xpath ('.//div[@data-testid="reply"]').text
    retweet_cnt = card.find_element_by_xpath ('.//div[@data-testid="retweet"]').text
    like_cnt =  card.find_element_by_xpath ('.//div[@data-testid="like"]').text
    tweet = (username, handle, postdate ,text, reply_cnt, retweet_cnt, like_cnt)
        
    return tweet

# %%
card = driver.find_elements_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/section/div/div/div[4]/div/div/article')
username = card.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[2]/div/section/div/div/div[1]/div/div/article/div/div/div/div[2]/div[2]/div[1]/div/div').text
handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text
postdate = card.find_element_by_xpath('//time').get_attribute('datetime')
comment = card.find_element_by_xpath ('//div[2]/div[2]/div[1]').text
responding = card.find_element_by_xpath('//div[2]/div[2]/div[2]').text 
text =c omment + responding
reply_cnt = card.find_elem ent_by_xpath ('.//div[@data-testid="reply"]').text
retweet_cnt = card.find_element_by_xpath ('.//div[@data-testid="retweet"]').text
like_cnt =  card.find_element_by_xpath ('.//div[@data-testid="like"]').text
tweet = (username, handle, postdate ,text, reply_cnt, retweet_cnt, like_cnt)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10604/771178914.py in <module>
# ----> 1 page_cards = driver.find_element_by_xpath('//div[@data-testid="tweet"]')
#       2 username = page_cards.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div[1]/div/div[2]/div/section/div/div/div[1]/div/div/article/div/div/div/div[2]/div[2]/div[1]/div/div').text
#       3 handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text
#       4 postdate = card.find_element_by_xpath('//time').get_attribute('datetime')
#       5 comment = card.find_element_by_xpath ('//div[2]/div[2]/div[1]').text
#
# ~\anaconda3\envs\scraping\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# ...
