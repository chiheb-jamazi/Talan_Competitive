# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd 
from time import sleep
import time

# %%
def connect_to_linkedin ():
    driver.get("https://www.linkedin.com/checkpoint/lg/sign-in-another-account")
    time.sleep(5)
    username = driver.find_element_by_id("username")
    username.send_keys("chiheb.jamazi@esprit.tn")
    pword = driver.find_element_by_id("password")
    pword.send_keys("Seawaymn2011&&")
    driver.find_element_by_xpath("//button[@type='submit']").click()

# %%
def scrolling_function ():
    SCROLL_PAUSE_TIME = 1.5
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        #uncomment to limit the number of scrolls
        #scroll_number += 1
        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    return

# %%
def get_posts_details(soupe):
    poste_date =[] 
    post_text = []
    post_nbreagi = []
    post_nb_comm = []
    post_nb_partage = []
    post_video_link = []
    containers =soupe.find_all('div', {'class':'occludable-update ember-view'})

    for container in containers:
        try:
            his=container.find('span', class_ ="visually-hidden")
    #         print(his.get_text().strip())
            poste_date.append(his.get_text().strip())
        except:
            poste_date.append('none')
        try:
            text=container.find('span', class_ ="break-words")
    #         print(text.get_text().strip())
            post_text.append(text.get_text().strip())
        except:
            post_text.append('none')
        try:
            nbreagi=container.find('span', class_ ="social-details-social-counts__reactions-count")
    #         print(nbreagi.get_text().strip())
            post_nbreagi.append(nbreagi.get_text().strip())
        except:
            post_nbreagi.append('none')  
        try:       
            nb_comm=container.find('button',class_="t-black--light t-12 hoverable-link-text")
    #         print(nb_comm.get_text().strip())
            post_nb_comm.append(nb_comm.get_text().strip())
        except:
            post_nb_comm.append('none')        

        try:        
            nb_partage=container.find('li',class_="social-details-social-counts__item social-details-social-counts__item--with-social-proof")
    #         print(nb_partage.get_text().strip())
            post_nb_partage.append(nb_partage.get_text().strip())
        except:
            post_nb_partage.append('none')
    return poste_date,post_text,post_nbreagi,post_nb_comm,post_nb_partage

# %%
def get_video_details(soupe):
    post_video_link = []
    containers =soupe.find_all('div', {'class':'occludable-update ember-view'})    
    for container in containers :
        try:
            video_link=container.find('video',class_="vjs-tech")
            videolink= video_link['src']
            post_video_link.append(videolink)
        except:
            post_video_link.append('none')
    return post_video_link

# %%
def get_Articles_details(soupe):
    articles = [] 
    containers =soupe.find_all('div', {'class':'occludable-update ember-view'})    
    for container in containers :
        try : 
            article_link = container.find("article")
            articles.append(article_link.a['href'])
        except:
            articles.append('none')
    return articles

# %%
def get_images_details(soupe):
    images = []
    containers =soupe.find_all('div', {'class':'occludable-update ember-view'})    
    for container in containers : 
        try:
            spans = container.find_all('img')
            image = spans[1]['src']
            images.append(image)  
        except :
            images.append('None') 
    return images

# %%
company = input("Enter your value: ")
page = "https://www.linkedin.com/company/"+company+"/"
driver=webdriver.Chrome(r'C:\\Users\\jchih\\\Documents\\selenium\\chromedriver.exe')
connect_to_linkedin ()
x=''
y=''
for i in ["videos", "articles","images"]:
    try :
        driver.get(page+"posts/?feedView="+i) 
        scrolling_function ()
        src =driver.page_source
        soupe =BeautifulSoup(src, 'lxml')
        data1 = get_posts_details(soupe)
        if i == 'videos':
            data2 = tuple(get_video_details(soupe))
            data = data1 + data2
            VideoData = pd.DataFrame(
            {'PostDate': data[0],
             'PostText': data[1],
             'PostLikes': data[2],       
             "PostComments":data[3],
             "PostShares": data[4],
             "PostVideos":data[5],
            })
        elif i == 'articles':
            data2 = tuple(get_Articles_details(soupe))
            data = data1 + data2
            ArticlesData = pd.DataFrame(
            {'PostDate': data[0],
             'PostText': data[1],
             'PostLikes': data[2],       
             "PostComments":data[3],
             "PostShares": data[4],
             "PostArticles":data[5],
            })
        elif i == 'images':
            data2 = tuple(get_images_details(soupe))
            data = data1 + data2
            ImagesData = pd.DataFrame(
            {'PostDate': data[0],
             'PostText': data[1],
             'PostLikes': data[2],       
             "PostComments":data[3],
             "PostShares": data[4],
             "PostImages":data[5],
            })
            



    except :
        print('we have an error')
# Out:
# Enter your value: talan

# %%
ImagesData.to_dict('records')
# Out:
# [{'PostDate': '1 week ago',
#   'PostText': '🏆 Nous sommes fiers d’avoir remporté Le prix du DRH Numérique  catégorie #Green organisé par l’ANDRH - Association Nationale des DRH : https://lnkd.in/gR3igG5j \U0001f7e9 Avec une stratégie RSE très ambitieuse qui place le rôle de la DRH au centre de notre déploiement ainsi que l’ensemble des directions des entités du Groupe, nous aspirons à être dans les années à venir un acteur exemplaire tant sur les aspects sociaux qu’environnementaux. 👉 Parmi les outils concrets qui illustrent cette stratégie, l’application MonEmpreinteCarbone by Talan apporte une réponse opérationnelle aux enjeux de mobilité. Il s’agit d’une solution digitale et ludique basée sur une démarche scientifique permettant de mesurer – et donc de réduire - l’empreinte carbone des collaborateurs sur leurs trajets «\xa0domicile – travail\xa0».👏 Bravo à toutes les équipes impliquées dans ces projets de transformation ! #Talan #RSE #DRHNUM2021 #DRH #RH #Empreintecarbone #carbone #transformation',
#   'PostLikes': 'none',
#   'PostComments': '8 comments',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 weeks ago',
#   'PostText': 'Et de deux ! Nous sommes fiers d\'avoir été récompensés aux Silicon Awards 2022.🥇 𝗠𝗲́𝗱𝗮𝗶𝗹𝗹𝗲 𝗱\'𝗼𝗿 𝗱𝗮𝗻𝘀 𝗹𝗮 𝗰𝗮𝘁𝗲́𝗴𝗼𝗿𝗶𝗲 "𝗘𝘅𝗽𝗲́𝗿𝗶𝗲𝗻𝗰𝗲 𝘂𝘁𝗶𝗹𝗶𝘀𝗮𝘁𝗲𝘂𝗿𝘀" 𝗽𝗼𝘂𝗿 𝗹\'𝗮𝗽𝗽𝗹𝗶𝗰𝗮𝘁𝗶𝗼𝗻 𝗦𝗗𝗥𝗔𝗽𝗽𝘀 : https://lnkd.in/gSCSetqw Saluée par la profession, cette application a été développée par les équipes de Talan en collaboration avec des réanimateurs du CHU Amiens-Picardie. Elle permet de prendre en charge les patients hospitalités en réanimation et placés sous assistance respiratoire.🥉 𝗠𝗲́𝗱𝗮𝗶𝗹𝗹𝗲 𝗱𝗲 𝗯𝗿𝗼𝗻𝘇𝗲 𝗱𝗮𝗻𝘀 𝗹𝗮 𝗰𝗮𝘁𝗲́𝗴𝗼𝗿𝗶𝗲 "𝗜𝗻𝗻𝗼𝘃𝗮𝘁𝗶𝗼𝗻" 𝗽𝗼𝘂𝗿 𝗹𝗲 𝗽𝗿𝗼𝗷𝗲𝘁 𝗱𝘂 𝗿𝗲́𝗮𝗻𝗶𝗺𝗮𝘁𝗲𝘂𝗿 𝗮𝘂𝗴𝗺𝗲𝗻𝘁𝗲́ : https://lnkd.in/gVjpjgap L\'objectif de ces solutions technologiques développées avec la start-up AiiNTENSE, est de fournir des outils d\'aide à la décision indispensables en réanimation pour évaluer au mieux l\'état neurologique des patients, et ainsi sauver des vies.Ces deux projets illustrent parfaitement notre raison d\'être "Nous croyons que seule une pratique humaniste de la technologie fera du nouvel âge numérique une ère de progrès pour tous." Car c\'est véritablement en étant au service de l\'humain que les technologies démultiplient leur potentiel.👏 Bravo aux équipes impliquées dans ces réalisations. 🎈 Rejoignez nos équipes : https://lnkd.in/ggmyqrma#Talan #TalanLabs #TalanHautsdeFrance #Amiens #Innovation #sante #TechHumaniste #UX NetMedia Group',
#   'PostLikes': 'none',
#   'PostComments': '20 comments',
#   'PostShares': '28 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 month ago',
#   'PostText': '🚀 Our Centre of Excellence in Malaga is growing so fast!\xa0We onboarded the first employee by Jan 17th\xa02022, and we are already over 20 people! We provide expertise and bespoke services in Cloud computing, Artificial Intelligence, Robotic Process Automation/ Smart Automation, Data and Blockchain, as well as technologies such as Java, .net, Angular, etc. 👉 To read more : https://lnkd.in/dUpPZj6h🎈 Stay tune and applied to our open jobs : https://lnkd.in/dP_vv7js#Talan #TalanSpain #Spain #Malaga #job #recruitment',
#   'PostLikes': 'none',
#   'PostComments': '13 comments',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '4 months ago',
#   'PostText': '[WEBINAR] A l\'occasion du Power Platform French Summit, Frank POIREAU [MVP] animera une conférence sur "Comment réussir l\'adoption des power users ?" demain à 17h.👀 Infos et inscription : https://lnkd.in/etE3JP8#Talan #PowerApps\xa0#PowerAutomate\xa0#Collaboration\xa0#Productivity #PowerBI\xa0#Microsoft365\xa0#Azure\xa0#microsoft365 #Microsoft #PowerVirtualAgent\xa0 aMS Community / Communauté aMS #PPFS2021',
#   'PostLikes': '42',
#   'PostComments': 'none',
#   'PostShares': '17 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '4 months ago',
#   'PostText': "[LE GRAND PITCH!] Mon handicap est invisible pas mes compétences ?\xa0Dans le CV, entretien ou dans la vie professionnelle on\xa0a parfois l'impression que la représentation du handicap\xa0prend le dessus sur les compétences. Pour découvrir\xa0les pitchs de David, Christophe, Alexandre et Aurélie c'est maintenant\xa0https://lnkd.in/eE-bUkxN#Talan\xa0#handicap\xa0#RSE\xa0#SEEPH\xa0#diversité\xa0#inclusion\xa0#emploi\xa0#pitch\xa0#concours\xa0#artoratoire\xa0#sociallearning\xa0#LGP\xa0Diversidées/\xa0Nicolas RECAPET/\xa0Chloé V./\xa0Laura SCHALLER/\xa0Céline Simon 🏈/\xa0yohanna chemouny/\xa0ARNAUD DRUGY",
#   'PostLikes': '17',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '4 months ago',
#   'PostText': "[LE GRAND PITCH!] Aujourd'hui et jusqu'au 26 novembre, nous vous donnons rdv sur https://lnkd.in/eE-bUkxN pour découvrir les pitchs des pépites et voter pour votre candidat préféré. 👉 Au programme aujourd'hui : 𝗣𝗼𝘂𝗿 𝗼𝘂 𝗰𝗼𝗻𝘁𝗿𝗲 𝗹𝗮 𝗥𝗤𝗧𝗛 ? Alors qui de Romain, Sylvain, Deniz ou Charline saura vous convaincre ? Chez Talan, nous avons déjà notre favoris 😊A vous de jouer !#Talan\xa0#handicap\xa0#RSE\xa0#SEEPH\xa0#diversité\xa0#inclusion\xa0#emploi\xa0#pitch\xa0#concours\xa0#artoratoire\xa0#sociallearning\xa0#LGP\xa0Diversidées/ Nicolas RECAPET/ Chloé V./ Laura SCHALLER/ Céline Simon 🏈/ yohanna chemouny/ ARNAUD DRUGY",
#   'PostLikes': '21',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 months ago',
#   'PostText': 'Cette distinction, dans la lignée du prix "Partenaire de l\'année 2020", montre la qualité et la motivation de toute l\'équipe Modern Workplace : https://lnkd.in/evnrG_pnNous sommes fiers que Powell Software nous attribue le statut de Gold Partner. Ce partenariat permet à nos clients de profiter pleinement de leurs environnements Microsoft\xa0O365 en lien avec un Intranet d’entreprise de dernière génération ! Bravo à toutes les équipes impliquées.#Talan #Powell #partenaire #Microsoft #MicrosoftO365 #ModernWorkplace',
#   'PostLikes': '42',
#   'PostComments': 'none',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '7 months ago',
#   'PostText': '🎇 We are pleased to announce the opening in September 2021 of a new Centre of Excellence in Málaga, in the south of Spain. The Talan Centre of Excellence in Málaga will provide expertise and bespoke services in Cloud computing, Artificial Intelligence, Robotic Process Automation / Smart Automation, Data and Blockchain, as well as technologies such as Java, .net, Angular, etc. 👉 Click to read more: https://lnkd.in/ejB-Bu9G#Talan #TalanSpain #Malaga #Spain #Opening #cloud #AI #RPA #Data',
#   'PostLikes': '134',
#   'PostComments': '5 comments',
#   'PostShares': '38 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '8 months ago',
#   'PostText': '[Replay] Comment faire évoluer les pratiques managériales au service de l’usager ?En Décembre dernier, Talan a eu le plaisir de recevoir son client Clermont Auvergne Métropole à l’occasion d’un webinar organisé autour d’une thématique plus que jamais d’actualité «\xa0Le lean management : une réponse aux enjeux de la transformation du secteur public.\xa0»  >> http://urlr.me/Kx9R3#talan #leanmanagement #rex',
#   'PostLikes': '18',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '8 months ago',
#   'PostText': '[REPLAY] Comment passer de la fidélité à une véritable préférence client ? Le replay de ce webinar de 30 minutes vous aidera à repenser les clés de la fidélisation en 2021. >> http://urlr.me/2WXRk#talan #fidélisation #client',
#   'PostLikes': '10',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '8 months ago',
#   'PostText': 'La Tunisie, très avancée dans les usages IT, utilise la technologie blockchain pour lutter contre le blanchiment d’argent. Imen Ayari, Directrice de l’innovation chez Talan shore, nous explique comment à travers cet article publié sur le site ZDNet France.>> https://urlz.fr/gfC3#Talan #Tunisie #Blockchain',
#   'PostLikes': '50',
#   'PostComments': '2 comments',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '10 months ago',
#   'PostText': '[MEET UP] Pour soutenir ses ambitions de développement, Talan recrute au UK ! Découvrez nos différents métiers lors de notre meet-up "What\'s your Talan?" le 30 juin à 13h30. Infos et inscriptions : https://lnkd.in/eJvQNvZDelphine DAMERY (Delivery Manager) et Amine RAMDANI (Functional & Technical Support Analyst) répondront à toutes vos questions sur Talan UK, nos projets clients, la vie à Londres, mais également des postes à pourvoir et l\'accompagnement et l\'intégration chez Talan en cas de mobilité...Le terrain n\'est rien sans les joueurs... A vous de jouer ! N\'attendez plus pour vous inscrire.#Talan #TalanUK #UK #mobilité #emploi #job',
#   'PostLikes': '12',
#   'PostComments': 'none',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '10 months ago',
#   'PostText': 'TGIF! Something new is coming to Talan Spain. Stay tuned!#Talan #TalanSpain',
#   'PostLikes': '138',
#   'PostComments': '2 comments',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '10 months ago',
#   'PostText': "[WEBINAR] Après une semaine consacrée à la RPA (Robotic Process Automation), Talan revient avec un retour d'expérience en collaboration avec\xa0Project Management Institute France - Nouvelle Aquitaine,\xa0EDF\xa0et le\xa0Microsoft Expérience Lab de Bordeaux. Rdv demain à 18h : https://lnkd.in/gh_i-wT🎈 Envie de travailler sur des projets RPA ? Rejoignez notre terrain de jeu https://lnkd.in/gp6XSqU#Talan #TalanNouvelleAquitaine #Bordeaux #RPA #Smartautomation",
#   'PostLikes': '41',
#   'PostComments': 'none',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '10 months ago',
#   'PostText': '[PANORAMA] Découvrez un panorama inspirant de cas d’usage de l’intelligence artificielle par secteur pour aider les entreprises à transformer leurs activités et s’inscrire dans un cercle vertueux. https://lnkd.in/gtQqgfU #Talan #TalanConsulting #ODD #developpementdurable #RSE #IA #intelligenceartificielle',
#   'PostLikes': '22',
#   'PostComments': '1 comment',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[Award]  🏆 Nous sommes très fiers d\'avoir reçu le "Citrix Microsoft Alliance" lors du Citrix Work Summit France 2021. Un grand merci à toute l\'équipe Citrix  et plus particulièrement à Guillaume Gesse pour son accompagnement dans notre partenariat. Un grand merci à toute les équipes  Ai3 / Talan pour le travail au quotidien sur les projets d\'accompagnement autour des offres Citrix Cloud chez nos clients. 🏆 En route pour de beaux projets Citrix / Microsoft / Talan en 2021 ! #microsoft #talan #citrix #P2PPatrice Noguero Fernande Meftah Serge Jacinto',
#   'PostLikes': '33',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '🎈 Nous sommes particulièrement fiers, pour la 7e année consécutive, de faire partie du Palmarès Great Place to Work France et d’être (encore une fois) dans le top five du classement 1000-2500 salariés.🎈 L’audit mené à cette occasion nous permet d’écouter nos collaborateurs et d’adapter notre stratégie RH en fonction de leurs nombreux feedbacks. Merci à tous de faire de Talan une entreprise où il fait, plus que jamais, bon vivre et travailler.Pour plus d’infos : https://lnkd.in/e9WweaT#talan #PalmaresGPTW2021 #GPTW #QVT #bestworkplaces21Patrick Dumoulin Great Place to Work® France',
#   'PostLikes': '114',
#   'PostComments': '4 comments',
#   'PostShares': '29 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[TALK] Venez découvrir Synapse Analytics lors de ce talk découverte animé par Erick Rojas. L’objectif de cette session est de mieux comprendre les services proposés et comment les adapter à son budget, ses besoins et son profil ! Rdv le 21 avril à 18h30. Infos et inscription : http://ow.ly/RwBS50Emxay#talan #Microsoft #Data #Synapse #AzureErick Rojas Le Wagon Jean-Baptiste Acquaviva Bertrand Bussac Julia Schena Raphael HEINRY Julien Lovato',
#   'PostLikes': '40',
#   'PostComments': '5 comments',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[EVENT] On the occasion of the Microsoft 365 Virtual Marathon, we invite you to join Frank POIREAU [MVP] for a conference dedicated to management meetings with Teams, on 26 April at 10:00 (Pacific time). More info : https://lnkd.in/eKEwjhZ#Talan #TalanLuxembourgPSF #Microsoft #Teams',
#   'PostLikes': '15',
#   'PostComments': '1 comment',
#   'PostShares': '10 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[HUMEUR] Enfant, colloc, chat, chien... qui vient interrompre vos réunions Teams ? Avec qui partagez-vous votre télétravail en confinement ? Racontez-nous !Merci à Camille Boulestin, de notre bureau Sud-Ouest pour ce dessin.#Talan #TalanSudOuest #dessin #confinement #teletravail',
#   'PostLikes': '58',
#   'PostComments': '3 comments',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': "[EVENEMENT] Sandra Bertrand vous donne rdv au Salon de la Data, pour la conférence « Comment un projet data en amélioration continue a posé les briques d'une transformation autour de la donnée ? » aux côtés de Groupama immobilier. Pour en savoir plus :https://lnkd.in/eyXyind#Talan #Data #SalonData2020",
#   'PostLikes': '22',
#   'PostComments': 'none',
#   'PostShares': '10 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[CLIENT] Une application développée et lancée en moins de trois mois et 1/3 des adhérents convaincu en 2 semaines. Découvrez notre cas client Synerciel https://lnkd.in/e4nHCVuLes équipes Synerciel – Salesforce et Talan ont lancé la nouvelle application My Synerciel :Les chiffres clés, 1 semaine après le lancement : - 30% des adhérents ont téléchargé l’application et ont créé leur compte sur l’espace digital. - 50% des partenaires ont créé leur compte sur l’espace digital. - Note moyenne supérieure à 4/5 dans les stores. #Talan #client #Salesforce #application',
#   'PostLikes': '48',
#   'PostComments': '2 comments',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': "[EVENEMENT] Convaincus que la transformation des entreprises passe notamment par l'innovation digitale, Talan s'appuie sur ses partenaires pour vous accompagner de bout en bout sur vos projets de transformation. Avec notre partenariat historique avec Oracle et fort de nos références sur des projets majeurs de transformation autour de l’ERP, nous sommes fiers de sponsoriser pour la première fois l’événement annuel de l’AUFO. https://lnkd.in/eeYpvsm#Talan #Oracle #AUFO #ERP",
#   'PostLikes': '19',
#   'PostComments': 'none',
#   'PostShares': '2 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '🎈 After France and Luxembourg, we are proud to announce our presence at the Great Place to Work Europe Awards (Category 500+ employees). 👉 https://lnkd.in/e-CUQa4Many thanks to our employees. We are proud of them for being more determined than ever to make Talan a best workplace.#Talan #EuropesBestWorkplaces #PalmaresGPTW2020 #GPTW #Europe',
#   'PostLikes': '22',
#   'PostComments': 'none',
#   'PostShares': '9 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': "🚀 Nous sommes ravis de vous annoncer notre rapprochement avec Ai3, Accélérateur d'innovation, entreprise spécialisée dans les solutions Microsoft, afin de devenir un acteur de référence des solutions Cloud et Modern workplace. Cliquez pour en savoir + : https://lnkd.in/eeCh_DBBienvenue aux équipes sur notre nouveau terrain de jeu. #Talan #AI3 #Cloud #ModernWorkplace #Microsoft",
#   'PostLikes': '225',
#   'PostComments': '21 comments',
#   'PostShares': '47 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': "[PORTRAIT] Arrivé chez Talan en tant qu'alternant en 2012, Olivier est maintenant Responsable de l'offre Maximo et co-anime une équipe de 70 consultants. Découvrez son parcours : https://lnkd.in/eQigbd7Qu'attendez-vous pour nous rejoindre ?#Talan #emploi #job #recrutement #portrait #EnterpriseAssetManagement #delivery",
#   'PostLikes': '93',
#   'PostComments': '2 comments',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': 'TRIBUNE] Pour Katty JULIEN, la crise du Covid-19 a nourri le désir d’un « monde d’après » dans le monde du travail. Le télétravail laisse entrevoir de profondes transformations des relations interpersonnelles et dresse en creux le portrait d’une nouvelle humanité. A lire sur Focus RH https://lnkd.in/dHG8y3P#Talan #Télétravail #Covid19',
#   'PostLikes': '28',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': 'La DSI d\'un grand groupe français de rang mondial dans le secteur du luxe a fait appel aux équipes de Talan pour les accompagner dans le choix et le déploiement d\'outils digitaux sur 5 continents. ➡ Lire le cas client : https://lnkd.in/ebENemmDans ce contexte de crise sanitaire, 3 grands "chantiers" ont émergé : 1⃣ Limiter le risque de failles de sécurité lié aux messageries instantanées sur téléphone mobile en ouvrant le service Kaizala.2⃣ Accompagner la migration « Skype to Teams » et renforcer le dispositif d’accompagnement au changement. 3⃣ Répondre à l\'émergence de nouveaux besoins métiers en déployant la signature électronique.➡ Pour lire le cas client : https://lnkd.in/ebENemm#Talan #Luxe #Covid19 #Microsoft365 #accompagnement #changement #digitalisation #SI',
#   'PostLikes': '70',
#   'PostComments': 'none',
#   'PostShares': '9 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': "💡 Léa Marianelli et Gaëtan Gougeon sont ingénieurs d'affaires chez Talan. Avec notre partenaires Salesforce, ils ont pu participer au projet humanitaire Lightforce Project. Ils se sont rendu au Sénégal pour aider à apporter de la lumière dans des villages ne disposant pas d'électricité. Ils nous racontent leur expérience : https://lnkd.in/e6RYKdf#Talan #lightforce #Senegal #humanitaire / Liter of Light / Liter of Light Italia / NEUROTECH SA",
#   'PostLikes': '174',
#   'PostComments': '3 comments',
#   'PostShares': '15 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': 'Olfa Chelbi fait le point sur le monde des fintechs et des groupes bancaires post-crise.A lire sur Silicon.fr : https://lnkd.in/gMsEavP#Talan #Fintech #banque #covid19 #crise',
#   'PostLikes': '39',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '1 year ago',
#   'PostText': '[PODCAST] Un virus peut-il déclencher une révolution numérique ?C’est la question posée par Bpifrance à Mehdi Houas et Paul-François Fournier pour aborder les changements et l’impact de la pandémie sur le monde de demain.À écouter sur :Apple Podcasts → https://apple.co/3cDvwNuDeezer → https://bit.ly/2MwynxpSpotify → https://spoti.fi/2UfKt21#Talan #Podcast #BPI #ServirLavenir #covid19 #numerique',
#   'PostLikes': '56',
#   'PostComments': 'none',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "Act4New is 30 ideas retained after the ideathon. Thanks to everyone who participated! Now it's up to you to make them possible! Go to https://lnkd.in/gytbbqy to register your team to our hackathon.#Act4New #MoreThanTech #Hackathon #Covid19 Syntec Numérique",
#   'PostLikes': '3',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': '[TRIBUNE] Covid-19, catalyseur de la santé numérique ? Le point de vue de Laurent Cervoni (Directeur I.A) pour Silicon.fr, à lire ici https://lnkd.in/gyT-tVD#Talan #IA #medecine #telemedecine #covid19',
#   'PostLikes': '28',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'With Act4New, we are given the opportunity to design together a post-covid19 future! 📌 https://lnkd.in/gWcpcRE 📌💡 You have an idea to propose? 👉 The ideathon is made for you.💻 You are rather more into development?👉 Build a team for the hackathon.More info on https://lnkd.in/gWcpcRE#MoreThanTech #COVID19 #Act4New #hackathon #ideathon #Talan Syntec Numérique',
#   'PostLikes': '9',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'Ideathon : the digital to address global challenges of a post covid-19 world! ➡ https://lnkd.in/grBqv9B ⬅You have ideas? You’d like to contribute to improve the post-lock down daily life of all?💡 Submit your ideas before May 5th on: https://lnkd.in/grBqv9B#Talan #Act4New #ideathon #MoreThanTech Syntec Numérique',
#   'PostLikes': '18',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "EN LIVE ! Aujourd'hui notre PDG Mehdi Houas présentait ses vœux depuis le Canada. C'était également l'occasion d'échanger avec nos collaborateurs sur le bilan de l'année écoulée, et les perspectives 2020. En live sur Workplace sans modération, ils pouvaient y poser toutes leurs questions.---LIVE! Today our CEO Mehdi Houas presented his wishes from Canada. It was also an opportunity to exchange with our employees on the results of the past year and the opportunites for 2020. Live without moderation on Workplace, where they could ask all their questions.#Talan #TalanInside #Canada #Live #wishes #workplace",
#   'PostLikes': '152',
#   'PostComments': '14 comments',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'Nous sommes ravis de vous annoncer notre  rapprochement avec MBR & DGM, sociétés spécialisées dans le conseil, le développement opérationnel et l’implémentation de solutions de gestion et de valorisation de la donnée. Cliquez pour en savoir plus : https://lnkd.in/dPe94PQ#Talan #TalanLuxembourg #Luxembourg #Conseil #Data',
#   'PostLikes': '80',
#   'PostComments': '4 comments',
#   'PostShares': '32 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'Le saviez-vous ? Chez Talan, nous avons lancé le podcast "Playfield" : https://lnkd.in/gnDGDHA. Dans chaque épisode, un collaborateur ou un partenaire du groupe Talan partage avec nous son parcours, ce qui l\'anime au quotidien et son propre terrain de jeu. A écouter sans modération !#talan #podcast #playfield',
#   'PostLikes': '67',
#   'PostComments': '1 comment',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': '[PORTRAIT] Chamseddine Jarraya, Consultant senior, revient sur son parcours, ses missions et son quotidien chez #Talan. Une interview à découvrir ici : https://lnkd.in/dPupAh3#TalanInside #Consulting',
#   'PostLikes': '16',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "[EVENEMENT] L'Afrique sera au cœur de la table ronde du France Digitale Day 2019. Mehdi Houas y partagera son point de vue, mercredi à 17h35. Infos et inscriptions : https://lnkd.in/gsNs6Fd#FDDay #Afrique",
#   'PostLikes': '140',
#   'PostComments': '2 comments',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "Avant de retrouver la frénésie la rentrée, et si vous preniez un peu de temps pour vous inspirer ? Le collectif Impact AI a publié un livre-blanc sur la nécessité d'un engagement collectif pour un usage responsable de l'#IA 👉🏽 https://bit.ly/30x4qC3",
#   'PostLikes': '78',
#   'PostComments': '1 comment',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'La #Blockchain est une technologie au coeur des enjeux de nos clients. Retrouvez notre conviction, nos missions et nos cas clients ➡️https://lnkd.in/gDr2hHfDes questions ? Jerome Bernard, Mathieu Lesueur, Imen Ayari et Alain Nicolas vous répondent 😉#AskTalan',
#   'PostLikes': '54',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "Plus qu'une technologie, nous sommes convaincus que l'#IA est une réponse opérationnelle à des bouleversements métier. Retrouvez notre philosophie, nos missions et nos cas clients ➡️ https://lnkd.in/gUed__EDes questions ? Philippe Lerique, Laurent Cervoni, Nicolas DOUSSINET et Elias Daher vous répondent 😉#AskTalan",
#   'PostLikes': '35',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'What are your current missions? At Talan, what is your playfield? We asked Brigitte GOUARIN, "Change & Optimization" Practice Leader in New York, a few questions ➡️ https://bit.ly/2S4jCDC',
#   'PostLikes': '21',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': "🇫🇷Nous serons au #WestAfricaCom qui se déroulera à Dakar les 10 et 11 juillet prochains. À cette occasion, Alan Price MBIDA, Partner chez Talan Consulting, interviendra mercredi 10 juillet à 15h25, ne manquez pas sa keynote ! Pour en savoir plus, cliquez ici : https://bit.ly/30cmYaS🇺🇸We will be at #WestAfricaCom which will take place in Dakar on July 10 and 11. On this occasion, Alan Price MBIDA, Partner at Talan Consulting, will be speaking on Wednesday 10 July at 15:25, don't miss his keynote! Informations here : https://bit.ly/2Xo4KBc",
#   'PostLikes': '8',
#   'PostComments': 'none',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '2 years ago',
#   'PostText': 'Nous sommes très heureux d\'annoncer l\'arrivée de Laure de La Raudiere et d\'Yves POILANE au sein du Comité d\'Orientation Stratégique de Talan. Retrouvez notre communiqué de presse ➡️https://bit.ly/2Xi7NLrPour Mehdi Houas : " Leur expertise et leur expérience professionnelle viendront enrichir notre réflexion collective, étape essentielle avant la mise en place de stratégies ambitieuses."',
#   'PostLikes': '68',
#   'PostComments': '4 comments',
#   'PostShares': '15 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Pourquoi devenir une entreprise apprenante ? Retrouvez le texte complet de Mehdi Houas en cliquant ici ➡️https://bit.ly/2IIKSon',
#   'PostLikes': '75',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'De passage à Viva Technology ? Venez échanger avec nos start-up : Energisme Prevision.io toguna et 360Learning Engagement Platform Ne manquez pas leurs pitchs 😀🔜 Découvrez notre programme complet : https://bit.ly/2He2y9d#VivaTech #VivaTalanCyril Hommel Maxence Boullet Francois Vergnolle Louis Marslen Claire Payen',
#   'PostLikes': '45',
#   'PostComments': '1 comment',
#   'PostShares': '15 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "[#TalanInside] Aujourd'hui on part à la découverte du bureau lyonnais. Qu'attendez-vous pour rejoindre nos équipes ? 👉 Cliquez pour voir nos offres à pourvoir : https://lnkd.in/dJwHtys #GPTW",
#   'PostLikes': '81',
#   'PostComments': '3 comments',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "[#TalanInside] La semaine dernière, les Talan's du Canada ont profité d'une soirée karting à Montréal. Bravo aux champions 🚥 *[#TalanInside] Last week, Talan Canada's Team enjoyed a karting evening in Montreal. Congratulations to the champions 🚥",
#   'PostLikes': '73',
#   'PostComments': '1 comment',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "🏃\u200d♀️🏃\u200d♂️ Ils l'ont fait ! Bravo aux lyonnais, rejoint par quelques parisiens sur la ligne de départ du Lyon Urban Trail hier !8, 14 et 24km pour les plus courageux : des côtes, des escaliers, de la descente et pas beaucoup de plat... #TalanInside #GPTW",
#   'PostLikes': '120',
#   'PostComments': '6 comments',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "🏉 Dimanche, les enfants de nos collaborateurs ont eu la chance d'encourager les joueurs Stade Français Paris sur la pelouse du Stade Jean Bouin. L'occasion pour eux de découvrir un nouveau terrain de jeu !",
#   'PostLikes': '103',
#   'PostComments': '2 comments',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "Nous sommes très fier·e·s de soutenir la Chaire Femmes et Sciences de l' Université Paris-Dauphine ! Celle-ci a pour vocation à développer et diffuser des travaux, recherches et réflexions, au niveau national et international, de femmes dans les métiers scientifiques. Pour plus d'informations, cliquez ici ➡️https://bit.ly/2XuQ84f",
#   'PostLikes': '104',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Children and adults with Down’s syndrome are all unique and amazing individuals. We had the great opportunity to collaborate with Fundación Síndrome de Down de Madrid in Spain, having a volunteering day to share an wonderful cooking experience together that we will never forget. THANK YOU FOR A GREAT DAY!---Todos los niños y adultos con Fundación Síndrome de Down de Madrid son únicos y maravillosos individuos. Tuvimos la oportunidad de colaborar con Down Madrid en España, teniendo un día de voluntariado para compartir una hermosa experiencia en la cocina que nunca olvidaremos. ¡GRACIAS POR UN DÍA GENIAL!',
#   'PostLikes': '46',
#   'PostComments': '2 comments',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "En 10 ans, nous avons accéléré notre croissance, fait évoluer notre logo, développé nos terrains de jeu en France et à l'international et multiplié quasiment par 20 notre nombre de consultant·e·s. Merci à vous tou·t·e·s ! #10yearschallenge",
#   'PostLikes': '176',
#   'PostComments': '1 comment',
#   'PostShares': '26 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "Cette année encore, nous étions au coeur des événements technologiques de référence, comme #VivaTech, l'Africa Blockchain Summit, le #ForumIA ou encore Denodo Datafest. Revivez nos moments forts de 2018 en quelques images ⬇️",
#   'PostLikes': '37',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Revivez notre année 2018 en quelques images ! Pour commencer notre rétrospective, retour sur des rencontres inspirantes qui ont marqué 2018 ⬇️✔️ Rencontres de Dumont d\'Urville autour des multipotentiels mais aussi du sport et du management avec Pascal Papé et Amélie OUDEA-CASTERA✔️Exposition "Gorgi Pluriel" à l\'occasion des 10 ans de Talan Tunisie✔️ Échanges avec l\'association Quelques Femmes du Numérique sur la blockchain✔️ Rencontres avec des personnalités politiques',
#   'PostLikes': '32',
#   'PostComments': 'none',
#   'PostShares': '9 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'The christmas spirit fills all our entities and countries! Happy holidays to all 🎅🎄🎁El espíritu navideño vive en todas nuestras entidades y países! Felices fiestas a todos 🎅🎄🎁',
#   'PostLikes': '178',
#   'PostComments': '2 comments',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "Talan Tunisie fête ses dix ans ! À l'occasion de cet anniversaire, Talan s'associe à la galerie AGorgi pour rendre hommage au célèbre peintre tunisien Abdelaziz Gorgi. Plus de 350 de ses œuvres sont exposées au cœur de la Médina de Tunis dans le Palais Kheïreddine ➡️https://bit.ly/2zYmxGqEnvie de faire partie de l'aventure tunisienne ? Postulez ici ➡️ https://bit.ly/2CaSBIk",
#   'PostLikes': '56',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'En Talan, ¡estamos orgullosos de ser patrocinadores ECO de la CAS Conferencia Agile Spain por primera vez!La agilidad en Talan nos permite capitalizar nuestras experiencias y reinventarnos en todo proyecto con pragmatismo y humildad, ya que tenemos creencias pero no certezas. No tememos experimentar ya que creemos que el futuro es un terreno de juego. Y tú, ¿cuál es tu terreno de juego? Únete en Alicante para explorar tu terreno de juego ágil para el futuro.------------------- At Talan, we are proud of being CAS Conferencia Agile Spain ECO sponsors for the first time!Agility at Talan allows us to capitalize on our experiences and reinvent ourselves on every project with pragmatism and humility. We are not afraid to experiment as we believe: The Future is a Playfield.And you, what is your playfield? Join us in Alicante to explore your Agile playfield for the future.',
#   'PostLikes': '18',
#   'PostComments': '1 comment',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': '" Notre activité lyonnaise connaît une forte croissance. (...) Il nous fallait donc des bureaux plus adaptés pour répondre à ces besoins et pour accueillir nos nouveaux collaborateurs. " Emmanuel PERRET, Directeur du bureau de Lyon, revient sur le déménagement de l\'équipe et sur cette nouvelle étape ➡️http://bit.ly/talan-lyon',
#   'PostLikes': '84',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "🇫🇷Paris, Lyon, Rennes, Madrid, Londres...nos bureaux se sont mis aux couleurs d'Halloween le temps d'une journée ! Pour rejoindre nos équipes diaboliques (ou presque ;)), rendez-vous sur notre site Carrière : https://bit.ly/2pAt7uR🇬🇧Paris, Lyon, Rennes, Madrid, London... our offices were on Halloween's colors for a day ! To join our evil (but nice ;) ) teams, click here : https://bit.ly/2pAt7uR",
#   'PostLikes': '93',
#   'PostComments': 'none',
#   'PostShares': '9 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Nous sommes partenaires du 2ème Forum de l\'intelligence artificielle, parrainé par Virginie Duby-Muller, députée de la Haute-Savoie et Cédric Villani, député de l\'Essonne. Rendez-vous le 13 novembre à la Maison de la Chimie ➡️https://bit.ly/2PCEakCÀ cette occasion, Philippe Lerique, AI Partner, interviendra sur la table-ronde "La maîtrise technologique de l\'intelligence artificielle : au coeur des enjeux de souveraineté ?" aux côtés de Nozha Boujemaa, directrice de l\'Institut DATAiA, Paula Forteza, députée des Français établis hors de France, Denis Masséglia, député du Maine-et-Loire, Serge Palaric, VP Enterprise South Europe & Embedded EMEA chez Nvidia et Eric Peters, expert auprès de la Commissaire européenne à l\'Économie et à la Société numériques, Mariya Gabriel.',
#   'PostLikes': '46',
#   'PostComments': 'none',
#   'PostShares': '9 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Talan USA has many job openings! Market Access Support, Java ION Developer and Python & Bash Support are only a few of the positions available to you. Don’t miss out on a great opportunity to be a part of Talan and work in NYC! Apply today ➡️ https://bit.ly/2OeKn51  You can also send your resume to recruitment@talan.com',
#   'PostLikes': '10',
#   'PostComments': 'none',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': "Évoluer professionnellement au sein de Talan tout en changeant de vie ? C'est possible ! Retrouvez le parcours de Bouchra KIDAH qui a quitté Paris pour prendre la tête du bureau du Luxembourg ➡️https://bit.ly/2Arjrv9Envie de rejoindre l'aventure luxembourgeoise ? Rendez-vous sur notre site Carrière ➡️https://bit.ly/2z1u2Lv",
#   'PostLikes': '63',
#   'PostComments': 'none',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'What an INCREDIBLE kick off of Talan in Spain! We just had our Open House in Madrid and we wanted to share. Welcome to our new playfield at Paseo de la Castellana 200, where the teams will be inspired to make our clients lives that much easier! Stay tuned as our team is growing very fast!---------Qué INCREÍBLE arranque de Talan en España! Hemos tenido nuestro Open House en Madrid y quisimos compartirlo. Bienvenid@s a nuestro nuevo terreno de juego en Paseo de la Castellana 200, donde los equipos podrán inspirarse para hacer la vida de nuestros clientes más sencilla. ¡Atentos, el equipo está creciendo muy rápidamente!',
#   'PostLikes': '90',
#   'PostComments': '7 comments',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
#   'PostText': 'Comment un outil de dataviz permet d’assister les décisions aux différents niveaux de l’entreprise (directions métiers, direction général, opérationnels) ? Retrouvez le retour d\'expérience de Talan avec Gares & Connexions et Toucan Toco "Data storytelling et pilotage opérationnel" lors du Salon de la Data à Nantes➡️https://bit.ly/2EuM7HuMerci à Arnaud Lutellier Eddy Amarouche Olivier Gautier Enguerran Delahaie',
#   'PostLikes': '27',
#   'PostComments': '1 comment',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '3 years ago',
# ...
#   'PostLikes': '26',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Dernier jour pour l\'exposition photos "Quelques Femmes du Numérique" dans nos locaux ! Si vous êtes de passage, n\'hésitez pas à y jeter un oeil ;) Les phrases inspirantes de nos Talan sont toujours disponibles en cliquant ici : http://bit.ly/2qOou4B',
#   'PostLikes': '13',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Vous avez une âme d'artiste et une énorme soif d'apprendre ? Et si vous preniez la même voie que Fanelli ? Retrouvez toutes les offres de TalanLabs en cliquant ici : http://bit.ly/2qVYMec",
#   'PostLikes': '19',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "[J-2] TalanSolutions organise un webinar avec Tableau le 31 mai prochain. Si vous n'êtes pas encore inscrit(e), c'est par ici : http://bit.ly/2pSxV3p",
#   'PostLikes': '12',
#   'PostComments': 'none',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Quel est l'aspect le plus challengeant du métier ? Quelles sont les différences entre un consultant junior ou senior ? Quelles sont les missions au quotidien ? ... Retrouvez toutes les réponses de nos consultants en cliquant ici : http://bit.ly/2q9Uvkp",
#   'PostLikes': '17',
#   'PostComments': '1 comment',
#   'PostShares': '2 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Kickstart your career at VivaTech -> Find us on the platform #TalentConnect, powered by Manpower ! Don't wait ! Apply now : http://bit.ly/2qjhcVG",
#   'PostLikes': '17',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Nous serons présents à New Crafts le 18 mai prochain. Venez nous retrouver stand n°2 :) Cliquez ici pour vous inscrire : http://bit.ly/2qb9XyZ',
#   'PostLikes': '6',
#   'PostComments': 'none',
#   'PostShares': '2 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Bravo aux Talan's qui ont parcouru dimanche les 10kms de Sport Ensemble pour Handicap International ! Ensemble nous sommes plus forts ! Retrouvez l'interview de Chloé, notre CHO, en cliquant ici : http://bit.ly/2r7UEs9",
#   'PostLikes': '49',
#   'PostComments': '1 comment',
#   'PostShares': '1 share',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Tenté(e) par les métiers du numérique ? Lina vous donne une autre bonne raison pour vous lancer ! Pour rejoindre nos équipes, cliquez ici : http://bit.ly/2pDw4LG',
#   'PostLikes': '17',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Tenté(e) par l'aventure Canada ? Nos consultants vous donnent 3 bonnes raisons de les rejoindre : http://bit.ly/2pNUHq4",
#   'PostLikes': '25',
#   'PostComments': '1 comment',
#   'PostShares': '10 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Processus de recrutement, mobilité internationale ou encore diversité des profils, nos consultants répondent à vos questions : http://bit.ly/2pcFugo',
#   'PostLikes': '28',
#   'PostComments': 'none',
#   'PostShares': '3 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': '[Parole d\'expert] "Sans sécurité, l\'engouement pour l\'IoT n\'aura pas lieu" - Pour François Gatineau, expert IoT chez Talan, la confiance est la clé de l\'explosion des ventes d\'objets connectés. Retrouvez sa tribune dans le Journal du Net en cliquant ici : http://bit.ly/2pUzNIP',
#   'PostLikes': '11',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Marketing des communautés, Data Socialisation et Chatbots, Rosalie Lacombe, Directrice Marketing et Communication du groupe Talan, commente son Top 3 de l'actualité Marketing Digital pour IT Social : http://bit.ly/2qtQOXk",
#   'PostLikes': '18',
#   'PostComments': 'none',
#   'PostShares': 'none',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Ce soir, nous accueillons Social Builder et la commission Femmes du Numérique pour un afterwork sur l'intrapreneuriat et les innovations managériales. Venez networker ! Cliquez ici pour vous inscrire (attention, places limitées) : http://bit.ly/2oy1pBz",
#   'PostLikes': '19',
#   'PostComments': 'none',
#   'PostShares': '2 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Join the Talan USA Adventure – start in Paris and land in NY! Looking for a Junior Python Developer to join our growing team! Apply here: http://ow.ly/V2UP30aQ6kB',
#   'PostLikes': '23',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Data Scientist est un métier très en vogue mais qui n'est pas toujours très bien connu. Il nécessite pourtant des qualités et des compétences très spécifiques... Saurez-vous retrouver celles qui manquent ? A vous de jouer ! (On vous aide : tous les indices sont sur le dessin)",
#   'PostLikes': '32',
#   'PostComments': 'none',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Talan Americas gives back!  We met students of MS223 - The Laboratory School of Finance & Technology, a Middle School in the South Bronx during their career day. Talan - building for tomorrow! http://ow.ly/FKMT30aNt2F',
#   'PostLikes': '17',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Retrouvons nous à la matinale connectée d'Objenious jeudi 30 mars au matin pour parler #IoT, maintenance prédictive, data value.... Inscrivez vous http://ow.ly/imAR30akHzB",
#   'PostLikes': '13',
#   'PostComments': 'none',
#   'PostShares': '2 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Félicitations au Mastère Spécialisé Business Intelligence de l'EISTI qui arrive en tête du classement Eduniversal 2017 ! 3 critères sont pris en compte : notoriété de la formation, salaires et débouchés et retour de satisfactions des étudiants. Talan est au coeur de la formation de ces futurs acteurs de la BI en délivrant l'ensemble des cours théoriques et une partie des cours pratiques. Pour découvrir le classement, cliquez ici : http://bit.ly/2nqcXVi",
#   'PostLikes': '39',
#   'PostComments': '2 comments',
#   'PostShares': '15 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Seminar Coming Up! In a few weeks, Talan Americas will hold its first incentive trip in the Bahamas with the US and Canadian teams. This is the result of great work from both teams through the past years. #SeeyouintheBahamas #Talaneverywhere',
#   'PostLikes': '48',
#   'PostComments': 'none',
#   'PostShares': '7 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Talan Canada wants you! Looking for FO Support specialists with strong skills in UNIX, SQL, and scripting. Apply here: http://ow.ly/h81930a5jEV',
#   'PostLikes': '13',
#   'PostComments': 'none',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Quels sont les enjeux du Big Data et quels impacts sur les entreprises ? Nicolas Doussinet, responsable Big Data chez TalanSolutions, revient sur les nouveaux challenges dus à l'explosion des volumes de données. Retrouvez son interview dans l'Usine Digitale en cliquant ici : http://bit.ly/2lKJHpG",
#   'PostLikes': '17',
#   'PostComments': 'none',
#   'PostShares': '6 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Vous vous demandez comment est la vie chez Talan ? Hugo Catherine, notre Directeur des Ressources Humaines,  vous parle recrutement, formation, projets internes et bien-être au travail dans l'Usine Digitale :) Retrouvez son interview en cliquant ici : http://bit.ly/2mojSzf",
#   'PostLikes': '36',
#   'PostComments': 'none',
#   'PostShares': '4 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': "Lyonnais, lyonnaises, vous cherchez un emploi dans les métiers de l'informatique, du Conseil AMOA ou encore dans la gestion de projet ? Venez nous rencontrer et découvrir nos opportunités mercredi 8 mars au Forum Rhônes Alpes. Pour vous inscrire, cliquez ici : https://www.forumorg.org/",
#   'PostLikes': '20',
#   'PostComments': '1 comment',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Ni lettre de motivation, ni CV, apportez simplement votre smartphone et venez nous rencontrer et nous convaincre autour d’un verre :) Nous serons présents à l’événement recrutement innovant « Dog finance Connect » pour présenter nos opportunités IT et Consulting IT. Inscriptions > http://bit.ly/2l3AFEN',
#   'PostLikes': '53',
#   'PostComments': 'none',
#   'PostShares': '8 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Talan Canada Recrute ! Vous cherchez de nouveaux défis en IT ? Nous recherchons de talentueux consultants en conseil IT et métier à Montréal et à Toronto. Si vous voulez travailler dans une ambiance de Start up, développer vos compétences et votre carrière tout en prenant du plaisir, envoyez-nous votre CV et tentez l’aventure Talan Canada ! http://ow.ly/hwCe3095Xwo',
#   'PostLikes': '56',
#   'PostComments': '7 comments',
#   'PostShares': '13 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Welcome to Toronto!Talan Conseils Canada is pleased to announce our new office in Toronto, reinforcing our presence in the finance arena. We will continue to develop Talan Americas towards other expertise such as Talan Solutions and other industries such as energy and telecoms. Come join us!https://lnkd.in/dEkY4rb',
#   'PostLikes': '67',
#   'PostComments': '3 comments',
#   'PostShares': '15 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'BIG DATA - Nous serons présents au Salon Big Data Paris pour échanger sur notre expertise avec les différents acteurs de la Data économie. Venez-nous y retrouver ! Pour vous inscirire, cliquez ici > http://bit.ly/1xFEpKO',
#   'PostLikes': '33',
#   'PostComments': '1 comment',
#   'PostShares': '16 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': 'Come visit the Talan NY HR team at the Fordham University Career Fair on January 25th! We’re looking for Finance and IT professionals to join our growing company! Hope to see you there https://lnkd.in/dyCjCsD',
#   'PostLikes': '20',
#   'PostComments': 'none',
#   'PostShares': '5 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'},
#  {'PostDate': '5 years ago',
#   'PostText': '« La création de TalanConsulting conforte la capacité de Talan à proposer une démarche complète, rigoureuse et créative, capable d’accompagner ses clients de la définition d’une vision à sa mise en œuvre. » Dominique Masutti, Directeur Général de TalanConsulting. Retrouvez le communiqué de presse du groupe en cliquant ici : https://lnkd.in/dCtUya9',
#   'PostLikes': '67',
#   'PostComments': '3 comments',
#   'PostShares': '19 shares',
#   'PostImages': 'https://media-exp1.licdn.com/dms/image/C5622AQFZ_wS8TJL-bw/feedshare-shrink_800/0/1648199617204?e=2147483647&v=beta&t=z-cILizV-3E_JeZPrzbEsC2gVkYQlAuoWFH7Cnb-y40'}]
